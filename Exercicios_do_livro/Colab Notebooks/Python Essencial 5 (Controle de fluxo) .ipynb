# %%
#o basico do if

if 10>15:
  print("10 é maior que 15")
else:
  print("10 não é maior que 15")

if 15>5:
  print("sim")

  print("================")

  temperatura =  25

  if temperatura > 30:
    print("temperatura alta")
  elif temperatura > 20:
    print("temperatura media")
  else:
    print("temperatura baixa")

    print("================")

Pontuacao = 75

if Pontuacao >= 90:
  print("A")
elif Pontuacao >= 80:
  print("B")
elif Pontuacao >= 70:
  print("C")
else:
  print("D")
# Out:
# 10 não é maior que 15
# sim
# ...
# temperatura media
# C

# %%
#exemplo de variavel

txt = "Hello World" #váriavel tipo string

print(txt) #está chamando a váriavel
# Out:
# Hello World

# %%
#exercicio 1

age = 21
phn = 15.996983902
name = "Emanuel"
last_name = "Rosa"
Country = "Brasil"
marryed = False

print(age)
print(phn)
print(name)
print(last_name)
print(Country)

print(type(age))
print(type(phn))
print(type(name))
print(type(last_name))
print(type(Country))
print(type(marryed))
# Out:
# 21
# 15.996983902
# Emanuel
# Rosa
# Brasil
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'bool'>

# %%
age = 21
marryed = False
#se não explicitar com print apenas o ultimo type é exibido
type(age)
type(marryed)
# Out:
# bool

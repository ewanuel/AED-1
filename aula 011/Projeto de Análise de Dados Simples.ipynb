# %%
vendas_agosto = {
    "04/08/2025": 2350,
    "05/08/2025": 1980,
    "06/08/2025": 2540,
    "07/08/2025": 2100,
    "08/08/2025": 3050,
    "11/08/2025": 2650,
    "12/08/2025": 2180,
    "13/08/2025": 2760,
    "14/08/2025": 2920,
    "15/08/2025": 3100,
    "18/08/2025": 2300,
    "19/08/2025": 2430,
    "20/08/2025": 2210,
    "21/08/2025": 2790,
    "22/08/2025": 2970,
    "25/08/2025": 3100,
    "26/08/2025": 2880,
    "27/08/2025": 2600,
    "28/08/2025": 2500,
    "29/08/2025": 3400
}

semana_1 = {
    "04/08/2025": 2350,
    "05/08/2025": 1980,
    "06/08/2025": 2540,
    "07/08/2025": 2100,
    "08/08/2025": 3050
}

semana_2 = {
    "11/08/2025": 2650,
    "12/08/2025": 2180,
    "13/08/2025": 2760,
    "14/08/2025": 2920,
    "15/08/2025": 3100
}

semana_3 = {
    "18/08/2025": 2300,
    "19/08/2025": 2430,
    "20/08/2025": 2210,
    "21/08/2025": 2790,
    "22/08/2025": 2970
}

semana_4 = {
    "25/08/2025": 3100,
    "26/08/2025": 2880,
    "27/08/2025": 2600,
    "28/08/2025": 2500,
    "29/08/2025": 3400
}

# Soma total do mês
sm_vnds_agst = sum(vendas_agosto.values())


# Média diária
md_vnds_agst = sm_vnds_agst/len(vendas_agosto)


#Soma semanal
ds_smn = 5
smn_ms = len(vendas_agosto) / ds_smn
sm_vnds_smn_agst = sm_vnds_agst / smn_ms


#Soma semana 1

smn1_sm = sum(semana_1.values())


smn1_ms = smn1_sm/len(semana_1)


smn2_sm = sum(semana_2.values())


smn2_ms = smn2_sm/len(semana_2)


smn3_sm = sum(semana_3.values())


smn3_ms = smn3_sm/len(semana_3)


smn4_sm = sum(semana_4.values())


smn4_ms = smn4_sm/len(semana_4)

#Média semanal geral
md_vnds_smn_agst = sm_vnds_smn_agst/smn_ms


#valor maxmo
max_val = max(vendas_agosto.values())
dia_max = [dia for dia, valor in vendas_agosto.items() if valor == max_val][0]


#valor maxmo
min_val = min(vendas_agosto.values())
dia_min = [dia for dia, valor in vendas_agosto.items() if valor == min_val][0]

#relatorio
print("=" * 50)
print("        RELATÓRIO DE VENDAS - AGOSTO 2025")
print("=" * 50)

print(f"\n📊 RESUMO GERAL DO MÊS:")
print(f"   • Total de vendas: R$ {sm_vnds_agst:,.2f}")
print(f"   • Média diária: R$ {md_vnds_agst:,.2f}")
print(f"   • Dias úteis analisados: {len(vendas_agosto)}")

print(f"\n🎯 VALORES EXTREMOS:")
print(f"   • Maior venda: R$ {max_val:,.2f} em {dia_max}")
print(f"   • Menor venda: R$ {min_val:,.2f} em {dia_min}")

print(f"\n📈 DESEMPENHO POR SEMANA:")
print(f"\n   SEMANA 1:")
print(f"   • Total: R$ {smn1_sm:,.2f}")
print(f"   • Média diária: R$ {smn1_ms:,.2f}")

print(f"\n   SEMANA 2:")
print(f"   • Total: R$ {smn2_sm:,.2f}")
print(f"   • Média diária: R$ {smn2_ms:,.2f}")

print(f"\n   SEMANA 3:")
print(f"   • Total: R$ {smn3_sm:,.2f}")
print(f"   • Média diária: R$ {smn3_ms:,.2f}")

print(f"\n   SEMANA 4:")
print(f"   • Total: R$ {smn4_sm:,.2f}")
print(f"   • Média diária: R$ {smn4_ms:,.2f}")

print(f"\n📋 DETALHAMENTO DIÁRIO:")
for semana_num, semana in enumerate([semana_1, semana_2, semana_3, semana_4], 1):
    print(f"\n   Semana {semana_num}:")
    for dia, valor in semana.items():
        print(f"   • {dia}: R$ {valor:,.2f}")

print("\n" + "=" * 50)
# Out:
# ...
#         RELATÓRIO DE VENDAS - AGOSTO 2025
# ...
#
# 📊 RESUMO GERAL DO MÊS:
#    • Total de vendas: R$ 52,810.00
#    • Média diária: R$ 2,640.50
#    • Dias úteis analisados: 20
#
# 🎯 VALORES EXTREMOS:
#    • Maior venda: R$ 3,400.00 em 29/08/2025
#    • Menor venda: R$ 1,980.00 em 05/08/2025
#
# 📈 DESEMPENHO POR SEMANA:
#
#    SEMANA 1:
#    • Total: R$ 12,020.00
#    • Média diária: R$ 2,404.00
#
#    SEMANA 2:
#    • Total: R$ 13,610.00
#    • Média diária: R$ 2,722.00
#
#    SEMANA 3:
#    • Total: R$ 12,700.00
#    • Média diária: R$ 2,540.00
#
#    SEMANA 4:
#    • Total: R$ 14,480.00
#    • Média diária: R$ 2,896.00
#
# 📋 DETALHAMENTO DIÁRIO:
#
#    Semana 1:
#    • 04/08/2025: R$ 2,350.00
#    • 05/08/2025: R$ 1,980.00
#    • 06/08/2025: R$ 2,540.00
#    • 07/08/2025: R$ 2,100.00
#    • 08/08/2025: R$ 3,050.00
#
#    Semana 2:
#    • 11/08/2025: R$ 2,650.00
#    • 12/08/2025: R$ 2,180.00
#    • 13/08/2025: R$ 2,760.00
#    • 14/08/2025: R$ 2,920.00
#    • 15/08/2025: R$ 3,100.00
#
# ...

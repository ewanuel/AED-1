# %%
def valida_cpf():
    cpf = input("Insira seu CPF:")

    if cpf.isdigit():
        cpf_lista = list(cpf)

        n = [int(digito) for digito in cpf_lista]

        soma = (n[0] * 10 + n[1] * 9 + n[2] * 8 + n[3] * 7 + n[4] * 6 + n[5] * 5 + n[6] * 4 + n[7] * 3 + n[8] * 2)

        resto = soma%11

        if resto < 2:
            dig1 = "0"
        else:
            dig1 = 11 - resto

        soma2 = (n[0] * 11 + n[1] * 10 + n[2] * 9 + n[3] * 8 + n[4] * 7 + n[5] * 6 + n[6] * 5 + n[7] * 4 + n[8] * 3 + dig1 * 2)

        resto2 = soma2%11

        if resto2 < 2:
            dig2 = "0"
        else:
            dig2 = 11 - resto2

        True
        
        print(resto)
        print(resto2)
        print(dig1)
        print(dig2)
        print (cpf_lista)
    else:
        False
        print("Apenas valores númericos")
        return False

# %%
from datetime import datetime

def valida_data():
    hoje = datetime.now().date()

    

    print("Insira a data de nascimento")
    dia = int(input("Dia: "))
    mes = int(input("Mês: "))
    ano = int(input("Ano: "))

    data_nasc = datetime(ano, mes, dia).date()

    idade = hoje.year - data_nasc.year - ((hoje.month, hoje.day) < (data_nasc.month, data_nasc.day))

    if idade < 18:
        print("Não é possível realizar o seu cadastro!")
        return False
    else:
        print("É possivel realizar o cadastro")
        return True

# %%
def exibir_menu():
    import random
    frases = ["A persistência realiza o impossível","Seus sonhos não precisam de plateia, eles só precisam de você","A persistência é o caminho do êxito","No meio da dificuldade encontra-se a oportunidade"]
    resp_usr = int(input("=========== MENU =========== \n [1]CADASTRAR \n [2]EXIBIR FRASE \n [3]Sair\n"))
    if resp_usr == 1:
        nome = input("Favor, informe seu primeiro nome:\n")
        sobre_nome = input("Favor, informe seu primeiro sobre nome:\n")
        cpf = valida_cpf()
        data_nascimento = valida_data()
        if not data_nascimento:
            print("Cadastro não realizado! Encerrando programa.")
            return False
        renda_bruta = float(input("Informe sua renda bruta:"))
        return True
        return print ("cadastro realizado com sucesso!")
    elif resp_usr == 2:
        random_frase = random.choice(frases)
        print(random_frase)
        return True
    elif resp_usr == 3:
        print("Bye bye!")
        return False
    else:
        print("Número inválido! Tente novamente.")

# %%
while exibir_menu():
    print("\n" + "="*30 + "\n")

print("Programa encerrado.")
# Out:
# =========== MENU ===========
#  [1]CADASTRAR
#  [2]EXIBIR FRASE
#  [3]Sair
#  1
# Favor, informe seu primeiro nome:
#  56
# Favor, informe seu primeiro sobre nome:
#  45
# Insira seu CPF: 565666585
# 9
# 10
# 2
# 1
# ['5', '6', '5', '6', '6', '6', '5', '8', '5']
# Insira a data de nascimento
# Dia:  09
# Mês:  06
# Ano:  2004
# É possivel realizar o cadastro
# Informe sua renda bruta: 1.800
# ...
# =========== MENU ===========
#  [1]CADASTRAR
#  [2]EXIBIR FRASE
#  [3]Sair
#  2
# A persistência é o caminho do êxito
#
# ...
# =========== MENU ===========
#  [1]CADASTRAR
#  [2]EXIBIR FRASE
#  [3]Sair
#  3
# Bye bye!
# Programa encerrado.

# %%
i
